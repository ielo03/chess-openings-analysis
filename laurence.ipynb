# %%
import chess.pgn
import pandas as pd

# Function to read a PGN file and extract data
def read_pgn(file_path):
    games_data = []
    with open(file_path) as pgn:
        while True:
            game = chess.pgn.read_game(pgn)
            if game is None:
                break
            # Extract data from the game
            # Example: game.headers["Event"], game.mainline_moves(), etc.
            extracted_data = {
                "Event": game.headers.get("Event", "N/A"),
                "Site": game.headers.get("Site", "N/A"),
                "White": game.headers.get("White", "N/A"),
                "Black": game.headers.get("Black", "N/A"),
                "Result": game.headers.get("Result", "N/A"),
                "WhiteElo": game.headers.get("WhiteElo", "N/A"),
                "BlackElo": game.headers.get("BlackElo", "N/A"),
                "Opening": game.headers.get("Opening", "N/A")  # Extract Opening
            }
            games_data.append(extracted_data)
    
    return pd.DataFrame(games_data)

# Path to your PGN file
file_path = 'lichess_db_standard_rated_2016-09_10k.feather'

# Read and process the PGN file
# chess_data = read_pgn('')
df = pd.read_feather(file_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Event            10000 non-null  object
#  1   Site             10000 non-null  object
#  2   White            10000 non-null  object
#  3   Black            10000 non-null  object
#  4   Result           10000 non-null  object
#  5   WhiteElo         10000 non-null  object
#  6   BlackElo         10000 non-null  object
#  7   WhiteRatingDiff  9996 non-null   object
#  8   BlackRatingDiff  9996 non-null   object
#  9   ECO              10000 non-null  object
#  10  Opening          10000 non-null  object
#  11  TimeControl      10000 non-null  object
#  12  Termination      10000 non-null  object
#  13  Moves            10000 non-null  object
# dtypes: object(14)
# memory usage: 1.1+ MB

# %%
df = df.dropna(subset=['WhiteRatingDiff'])
df = df[df['Termination'] != 'Abandoned']
df = df[~df['Event'].str.contains('Bullet')]
df = df[~df['Event'].str.contains('Correspondence')]

# %%
df.head()
# Out:
#                                                Event  \
# 2  Rated Classical tournament https://lichess.org...
# 3  Rated Blitz tournament https://lichess.org/tou...
# 6  Rated Blitz tournament https://lichess.org/tou...
# 7  Rated Classical tournament https://lichess.org...
# 8  Rated Blitz tournament https://lichess.org/tou...
#
#                            Site            White            Black Result  \
# 2  https://lichess.org/13YDbkSL          ronniak     Ezequielluis    1-0
# 3  https://lichess.org/Tongyamf       URDEADMEAT           brumia    1-0
# 6  https://lichess.org/Sd0Jxl5Y      cougarsrule       iwangrozni    1-0
# 7  https://lichess.org/rYs8Rj2X  hassenrouissi28            MedRx    1-0
# 8  https://lichess.org/D7LEbazz            mrbnk  Thiago_Siqueira    0-1
#
#   WhiteElo BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 2     1801     1768             +10             -10  A04
# 3     1627     1659             +13             -14  D00
# 6     1763     1756             +11             -11  B76
# 7     1500     1500            +162            -163  A45
# 8     1973     1946             -12             +12  B22
#
#                                              Opening TimeControl  \
# 2           Zukertort Opening: Black Mustang Defense       600+0
# 3              Queen's Pawn Game: Chigorin Variation       180+0
# 6  Sicilian Defense: Dragon Variation, Yugoslav A...       180+0
# 7                                        Indian Game       600+0
# 8                 Sicilian Defense: Alapin Variation       180+0
#
#     Termination                                              Moves
# 2        Normal  1. Nf3 Nc6 2. g3 Nf6 3. Bg2 g6 4. d4 d5 5. O-O...
# 3  Time forfeit  1. d4 d5 2. Nc3 f6 3. Bf4 e6 4. a3 Bd6 5. Bg3 ...
# 6  Time forfeit  1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 Nf6 5. ...
# 7        Normal  1. d4 Nf6 2. Bf4 d5 3. h3 Nc6 4. e3 Bf5 5. a3 ...
# 8        Normal  1. e4 c5 2. c3 e6 3. d4 cxd4 4. cxd4 d6 5. Nc3...

# %%
df['Result'].value_counts()
# Out:
# Result
# 1-0        3517
# 0-1        3275
# 1/2-1/2     284
# Name: count, dtype: int64

# %%
df_clean = df.drop(['Site', 'White', 'Black'], axis=1)
# We can change the min # move here
min_total_moves = 8
df_clean = df_clean[df_clean['Moves'].str.contains(' ' + repr(min_total_moves) + '\. ') | df_clean['Moves'].str.contains('#')]

df_clean
# Out:
#                                                   Event   Result WhiteElo  \
# 2     Rated Classical tournament https://lichess.org...      1-0     1801
# 3     Rated Blitz tournament https://lichess.org/tou...      1-0     1627
# 6     Rated Blitz tournament https://lichess.org/tou...      1-0     1763
# 7     Rated Classical tournament https://lichess.org...      1-0     1500
# 8     Rated Blitz tournament https://lichess.org/tou...      0-1     1973
# ...                                                 ...      ...      ...
# 9995                               Rated Classical game      1-0     1712
# 9996                                   Rated Blitz game      0-1     1979
# 9997                                   Rated Blitz game  1/2-1/2     1700
# 9998                                   Rated Blitz game      1-0     1836
# 9999                                   Rated Blitz game      1-0     1451
#
#      BlackElo WhiteRatingDiff BlackRatingDiff  ECO  \
# 2        1768             +10             -10  A04
# 3        1659             +13             -14  D00
# 6        1756             +11             -11  B76
# 7        1500            +162            -163  A45
# 8        1946             -12             +12  B22
# ...       ...             ...             ...  ...
# 9995     1741             +24             -13  B50
# 9996     2010             -10              +9  D15
# 9997     1754              +2              -1  D01
# 9998     1870             +16             -11  C45
# 9999     1479             +11             -12  B21
#
#                                                 Opening TimeControl  \
# 2              Zukertort Opening: Black Mustang Defense       600+0
# 3                 Queen's Pawn Game: Chigorin Variation       180+0
# 6     Sicilian Defense: Dragon Variation, Yugoslav A...       180+0
# 7                                           Indian Game       600+0
# 8                    Sicilian Defense: Alapin Variation       180+0
# ...                                                 ...         ...
# 9995                   Sicilian Defense: Delayed Alapin      600+10
# 9996              Slav Defense: Three Knights Variation       180+0
# 9997              Queen's Pawn Game: Chigorin Variation       180+3
# 9998                                        Scotch Game       180+2
# 9999                    Sicilian Defense: Morphy Gambit       180+0
#
#        Termination                                              Moves
# 2           Normal  1. Nf3 Nc6 2. g3 Nf6 3. Bg2 g6 4. d4 d5 5. O-O...
# 3     Time forfeit  1. d4 d5 2. Nc3 f6 3. Bf4 e6 4. a3 Bd6 5. Bg3 ...
# 6     Time forfeit  1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 Nf6 5. ...
# 7           Normal  1. d4 Nf6 2. Bf4 d5 3. h3 Nc6 4. e3 Bf5 5. a3 ...
# 8           Normal  1. e4 c5 2. c3 e6 3. d4 cxd4 4. cxd4 d6 5. Nc3...
# ...            ...                                                ...
# 9995        Normal  1. e4 { [%eval 0.3] } 1... c5 { [%eval 0.34] }...
# 9996        Normal  1. d4 c6 2. c4 d5 3. Nc3 Nf6 4. Nf3 Bf5 5. Bf4...
# 9997        Normal  1. d4 Nf6 2. Nc3 d5 3. h3 Bf5 4. Bg5 e6 5. a3 ...
# 9998        Normal  1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. Nxd4 d6 5. B...
# 9999        Normal  1. e4 c5 2. d4 cxd4 3. Nf3 Nf6 4. Bd3 e5 5. c3...
#
# [6958 rows x 11 columns]

# %%
df_clean['Moves'].value_counts()
# Out:
# Moves
# 1. e4 e5 2. Qh5 Nc6 3. Bc4 Nf6 4. Qxf7#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    3
# 1. Nf3 Nc6 2. g3 Nf6 3. Bg2 g6 4. d4 d5 5. O-O Bg7 6. Bf4 O-O 7. Nc3 Bf5 8. Nh4 Qd7 9. Nxf5 Qxf5 10. a3 Ng4 11. Nxd5 Nxd4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# 1. e4 { [%eval 0.41] } 1... e5 { [%eval 0.41] } 2. d4 $6 { [%eval -0.1] } 2... d6 $6 { [%eval 0.58] } 3. d5 { [%eval 0.21] } 3... c6 { [%eval 0.25] } 4. Nc3 { [%eval 0.15] } 4... Bd7 { [%eval 0.26] } 5. Nf3 { [%eval 0.26] } 5... f6 $2 { [%eval 1.56] } 6. Be3 { [%eval 1.43] } 6... g5 $4 { [%eval 4.68] } 7. dxc6 $2 { [%eval 2.05] } 7... Bxc6 { [%eval 2.33] } 8. Nb5 $2 { [%eval 0.84] } 8... Qa5+ $2 { [%eval 1.93] } 9. c3 $2 { [%eval -0.01] } 9... Bxb5 { [%eval -0.25] } 10. Bxb5+ $2 { [%eval -2.31] } 10... Qxb5 { [%eval -2.25] } 11. Qc2 { [%eval -2.36] } 11... Nd7 { [%eval -2.28] } 12. c4 { [%eval -2.49] } 12... Qb4+ { [%eval -2.39] } 13. Nd2 { [%eval -2.33] } 13... Nc5 { [%eval -2.41] } 14. O-O { [%eval -2.37] } 14... Qb6 $6 { [%eval -1.81] } 15. Nb3 $6 { [%eval -2.54] } 15... Nxb3 $4 { [%eval 3.37] } 16. Bxb6 { [%eval 3.46] } 16... Nxa1 { [%eval 3.39] } 17. Qa4+ { [%eval 3.28] } 17... Ke7 $6 { [%eval 4.0] } 18. Rxa1 { [%eval 3.98] } 18... Bg7 $6 { [%eval 4.67] } 19. Rd1 { [%eval 4.54] } 19... Nh6 { [%eval 4.45] } 20. Qb4 $2 { [%eval 1.59] } 20... Rhd8 $4 { [%eval 9.05] } 21. h3 $4 { [%eval 0.0] } 21... axb6 { [%eval 0.0] } 22. Qxb6 { [%eval 0.0] } 22... Nf7 { [%eval 0.48] } 23. Qxb7+ { [%eval 0.36] } 23... Ke6 $2 { [%eval 1.78] } 24. Qd5+ { [%eval 1.71] } 24... Ke7 { [%eval 1.62] } 25. c5 { [%eval 1.6] } 25... dxc5 { [%eval 1.54] } 26. Qb7+ { [%eval 1.12] } 26... Ke6 { [%eval 1.25] } 27. b4 $4 { [%eval -6.21] } 27... Rxd1+ { [%eval -6.13] } 28. Kh2 { [%eval -6.11] } 28... Rdd8 { [%eval -5.8] } 29. bxc5 { [%eval -5.74] } 29... Rxa2 $4 { [%eval 0.0] } 30. c6 $4 { [%eval -6.33] } 30... Rxf2 $4 { [%eval -2.39] } 31. Qb3+ $2 { [%eval -3.44] } 31... Kd6 $4 { [%eval 0.0] } 32. Qd5+ $6 { [%eval -0.67] }                                                                                                                                                                                                                                                                                                                 1
# 1. e4 { [%eval 0.35] } 1... d5 { [%eval 0.61] } 2. exd5 { [%eval 0.61] } 2... Qxd5 { [%eval 0.64] } 3. Nc3 { [%eval 0.6] } 3... Qd8 { [%eval 0.62] } 4. Bc4 { [%eval 0.62] } 4... a6 { [%eval 0.64] } 5. Nge2 { [%eval 0.19] } 5... Nf6 { [%eval 0.26] } 6. O-O { [%eval 0.14] } 6... e6 { [%eval 0.2] } 7. d3 { [%eval -0.07] } 7... b5 { [%eval 0.04] } 8. Bb3 { [%eval 0.1] } 8... Bb7 { [%eval 0.03] } 9. Bg5 { [%eval -0.17] } 9... Nbd7 { [%eval -0.21] } 10. Ng3 { [%eval -0.34] } 10... Bb4 { [%eval -0.08] } 11. f3 { [%eval -0.19] } 11... Bxc3 { [%eval 0.26] } 12. bxc3 { [%eval 0.24] } 12... O-O { [%eval 0.26] } 13. Ne4 { [%eval 0.11] } 13... c5 { [%eval 0.19] } 14. Qe1 { [%eval 0.02] } 14... Bxe4 { [%eval 0.21] } 15. fxe4 { [%eval 0.0] } 15... Qb6 { [%eval 0.18] } 16. Kh1 { [%eval -0.07] } 16... Rac8 { [%eval 0.36] } 17. a4 $6 { [%eval -0.26] } 17... h6 { [%eval 0.2] } 18. Be3 { [%eval 0.34] } 18... Ng4 { [%eval 0.42] } 19. Bd2 $6 { [%eval -0.12] } 19... Qd6 { [%eval 0.29] } 20. g3 $2 { [%eval -1.51] } 20... h5 $2 { [%eval 0.32] } 21. axb5 { [%eval 0.35] } 21... axb5 { [%eval 0.36] } 22. Bf4 { [%eval 0.32] } 22... Qe7 { [%eval 0.42] } 23. h3 { [%eval -0.05] } 23... Nge5 { [%eval 0.17] } 24. Qe2 { [%eval 0.08] } 24... g6 $6 { [%eval 0.84] } 25. Ra7 { [%eval 0.85] } 25... Qd6 $2 { [%eval 3.55] } 26. Rxd7 { [%eval 3.53] } 26... Qxd7 { [%eval 3.37] } 27. Bxe5 { [%eval 3.22] } 27... Ra8 $2 { [%eval 4.32] } 28. Bf6 { [%eval 3.93] } 28... Qc7 { [%eval 4.25] } 29. Qe3 { [%eval 4.13] } 29... Kh7 { [%eval 4.13] } 30. g4 $2 { [%eval 2.76] } 30... Rg8 $2 { [%eval 3.98] } 31. gxh5 { [%eval 3.94] } 31... gxh5 { [%eval 3.87] } 32. e5 $2 { [%eval 1.89] } 32... Rg6 $2 { [%eval 3.67] } 33. Qe2 $6 { [%eval 2.94] } 33... Qc6+ { [%eval 2.92] } 34. Kh2 { [%eval 2.73] } 34... Rag8 $4 { [%eval #3] } 35. Qxh5+ { [%eval #2] } 35... Rh6 { [%eval #2] } 36. Qe2 $4 { [%eval 3.65] } 36... Rhg6 $4 { [%eval #3] } 37. Rf2 $4 { [%eval 3.74] } 37... Qa6 $4 { [%eval #3] } 38. Qd1 $4 { [%eval 3.57] } 38... Rg1 $4 { [%eval #1] } 39. Qh5#    1
# 1. e3 e5 2. b3 Nf6 3. Bb2 Nc6 4. g3 Bc5 5. a3 d5 6. Bb5 O-O 7. Bxc6 bxc6 8. Bxe5 Re8 9. Bb2 Ba6 10. f3 d4 11. Kf2 dxe3+ 12. Kg2 exd2 13. Qxd2 Nd5 14. Qa5 Be3 15. Qxa6 Bxg1 16. Rxg1 Ne3+ 17. Kh3 Qd7+ 18. g4 Re6 19. Qb7 Rh6+ 20. Kg3 Qd6+ 21. f4 Re8 22. Re1 Rf6 23. Bxf6 Qxf6 24. c3 h6 25. Kf3 Qh4 26. Rxe3 Qh3+ 27. Kf2 Qxe3+ 28. Kg2 Qxf4 29. Qxc6 Qxg4+ 30. Kf1 Qe2+ 31. Kg1 Qe1+ 32. Kg2 Re2+ 33. Kf3 Qf1+ 34. Kg3 Re3+ 35. Kg4 Qh3+ 36. Kf4 Re6 37. Qf3 Rf6+ 38. Ke4 Qxf3+ 39. Kd4 Rf4+ 40. Kc5 Qh5+ 41. Kc6 Rf6+ 42. Kb7 Qb5+ 43. Ka8 Rd6 44. Kxa7 Ra6#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# 1. e4 d5 2. e5 c5 3. d4 Nc6 4. Nf3 Bg4 5. dxc5 e6 6. Bb5 Bxc5 7. O-O a6 8. Ba4 b5 9. Bb3 Nd4 10. Nxd4 Bxd1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# 1. e3 g6 2. Bc4 d6 3. Qf3 Nf6 4. h3 Nc6 5. Bb5 Bf5 6. Bxc6+ Nd7 7. Bxb7 Rb8 8. Be4 e6 9. Bxf5 exf5 10. e4 Nf6 11. exf5 Qe7+ 12. Qe2 Bh6 13. fxg6 hxg6 14. Qxe7+ Kxe7 15. Nf3 Rb5 16. Nc3 Re5+ 17. Nxe5 dxe5 18. O-O Nh5 19. Re1 Rd8 20. Rxe5+ Kf6 21. Rd5 Re8 22. d3 Re1+ 23. Kh2 Bxc1 24. Na4 Bf4+ 25. g3 Rxa1 26. gxf4 Nxf4 27. Rd4 Ne2 28. Rd7 Rxa2 29. Nc3 Nxc3 30. bxc3 Rxc2 31. Rxc7 Rxf2+ 32. Kg3 Rd2 33. d4 Rd3+ 34. Kh2 g5 35. Rxa7 Rxc3 36. d5 Ke5 37. Ra5 f5 38. d6+ Kxd6 39. Rxf5 Rc2+ 40. Kg3 Ke6 41. Rxg5 Rc3+ 42. Kg4 Re3 43. h4 Re4+ 44. Kh3 Kf6 45. Rg4 Kf5 46. Rxe4 Kxe4 47. Kg4 Ke5 48. h5 Kf6 49. Kf4 Kf7 50. Kf5 Kg8 51. Kg6 Kf8 52. h6 Kg8 53. h7+ Kh8 54. Kh6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# 1. e4 e5 2. Nf3 Nc6 3. Bc4 Bc5 4. O-O d6 5. c3 Bg4 6. h3 Bxf3 7. Qxf3 Qf6 8. Qe2 Nge7 9. d4 exd4 10. Nd2 O-O 11. Nf3 dxc3 12. bxc3 Qxc3 13. Bb2 Qb4 14. a3 Qb6 15. Ng5 h6 16. Nf3 Ng6 17. e5 Ngxe5 18. Nxe5 dxe5 19. Rae1 Kh8 20. Qh5 Qxb2 21. Re4 Bd4 22. Rh4 Ne7 23. Bd3 Ng6 24. Qf5 Rae8 25. g4 Bxf2+ 26. Rxf2 Qc1+ 27. Kg2 Qg5 28. Qxg5 Nxh4+ 29. Qxh4 f6 30. Qg3 Rd8 31. Rf5 Rd5 32. h4 Rfd8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# 1. e4 c5 2. b3 Nc6 3. Bb2 e5 4. g3 d6 5. f4 Nf6 6. Nf3 Bg4 7. Bg2 Nxe4 8. O-O Qc8 9. fxe5 Nxe5 10. Bxe5 dxe5 11. d3 Nf6 12. Qe1 Bd6 13. Nxe5 Bxe5 14. Qxe5+ Kf8 15. Nd2 Rb8 16. Ne4 b6 17. Nxf6 gxf6 18. Qd6+ Kg8 19. Qxf6 Be6 20. Rae1 c4 21. Qg5+ Kf8 22. Bh3 Bxh3 23. Qe7+ Kg8 24. Qxf7#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# 1. e4 c5 2. d4 cxd4 3. Nf3 Nf6 4. Bd3 e5 5. c3 Bc5 6. Bg5 O-O 7. b4 Bb6 8. O-O h6 9. Bxf6 Qxf6 10. a4 Nc6 11. b5 Na5 12. c4 Qe6 13. Qd2 Nxc4 14. Bxc4 Qxc4 15. Nxe5 Qe6 16. Nd3 Qxe4 17. Re1 Qd5 18. a5 Bc7 19. h3 Qd6 20. g3 a6 21. b6 Bd8 22. Re4 Bf6 23. Nf4 Qc5 24. Ra4 d5 25. Rexd4 Bxd4 26. Rxd4 Bf5 27. Rxd5 Qe7 28. Rxf5 g6 29. Rd5 Rad8 30. Rxd8 Rxd8 31. Qe3 Rd1+ 32. Kg2 Rxb1 33. Qxe7 Kg7 34. Qxb7 Ra1 35. Qxa6 g5 36. b7 Rb1 37. Qa7 gxf4 38. b8=Q Rxb8 39. Qxb8 fxg3 40. fxg3 Kg6 41. a6 Kf6 42. a7 Kg5 43. a8=Q h5 44. Qa4 h4 45. Qbb5+ Kf6 46. Qaa6+ Kg7 47. Qbb7 Kf8 48. Qf6 Kg8 49. Qfxf7+ Kh8 50. Qg7#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# Name: count, Length: 6956, dtype: int64

# %%
df_clean.infer_objects(copy=False)
df_clean['Result'] = df_clean['Result'].replace({'1-0': 1.0, '0-1': 0.0, '1/2-1/2': 0.5})
df_clean.drop(['Event', 'BlackElo', 'BlackRatingDiff', 'TimeControl', 'Termination'], axis=1, inplace=True)
df_clean
# Out:
#       Result WhiteElo WhiteRatingDiff  ECO  \
# 2        1.0     1801             +10  A04
# 3        1.0     1627             +13  D00
# 6        1.0     1763             +11  B76
# 7        1.0     1500            +162  A45
# 8        0.0     1973             -12  B22
# ...      ...      ...             ...  ...
# 9995     1.0     1712             +24  B50
# 9996     0.0     1979             -10  D15
# 9997     0.5     1700              +2  D01
# 9998     1.0     1836             +16  C45
# 9999     1.0     1451             +11  B21
#
#                                                 Opening  \
# 2              Zukertort Opening: Black Mustang Defense
# 3                 Queen's Pawn Game: Chigorin Variation
# 6     Sicilian Defense: Dragon Variation, Yugoslav A...
# 7                                           Indian Game
# 8                    Sicilian Defense: Alapin Variation
# ...                                                 ...
# 9995                   Sicilian Defense: Delayed Alapin
# 9996              Slav Defense: Three Knights Variation
# 9997              Queen's Pawn Game: Chigorin Variation
# 9998                                        Scotch Game
# 9999                    Sicilian Defense: Morphy Gambit
#
#                                                   Moves
# 2     1. Nf3 Nc6 2. g3 Nf6 3. Bg2 g6 4. d4 d5 5. O-O...
# 3     1. d4 d5 2. Nc3 f6 3. Bf4 e6 4. a3 Bd6 5. Bg3 ...
# 6     1. e4 c5 2. Nf3 Nc6 3. d4 cxd4 4. Nxd4 Nf6 5. ...
# 7     1. d4 Nf6 2. Bf4 d5 3. h3 Nc6 4. e3 Bf5 5. a3 ...
# 8     1. e4 c5 2. c3 e6 3. d4 cxd4 4. cxd4 d6 5. Nc3...
# ...                                                 ...
# 9995  1. e4 { [%eval 0.3] } 1... c5 { [%eval 0.34] }...
# 9996  1. d4 c6 2. c4 d5 3. Nc3 Nf6 4. Nf3 Bf5 5. Bf4...
# 9997  1. d4 Nf6 2. Nc3 d5 3. h3 Bf5 4. Bg5 e6 5. a3 ...
# 9998  1. e4 e5 2. Nf3 Nc6 3. d4 exd4 4. Nxd4 d6 5. B...
# 9999  1. e4 c5 2. d4 cxd4 3. Nf3 Nf6 4. Bd3 e5 5. c3...
#
# [6958 rows x 6 columns]
